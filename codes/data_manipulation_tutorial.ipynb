# %% [markdown]
# # 🧪 Data Manipulation Tutorial with Pandas
#
# This tutorial covers essential data manipulation techniques using **pandas** library, including reading/writing files, inspecting data, modifying columns, filtering, grouping, and more.
#
# When working with tabular data, such as spreadsheet, [pandas](https://pandas.pydata.org/pandas-docs/stable/index.html) is a well-known tool used in Python. In pandas, a data table is called as a `DataFrame`. Basically, it is just like your spreadsheet where you have columns, rows, and data in each cell.

# %%
# 📦 Import necessary libraries
import pandas as pd

# %% [markdown]
# ## 📄 Creating Dataframe
# ![DataFrame illustration](https://pandas.pydata.org/pandas-docs/stable/_images/01_table_dataframe.svg "DataFrame illustration taken from pandas.pydata.org")
#
# > Illustration is taken from [pandas.pydata.org](https://pandas.pydata.org)
#
# DataFrame is two-dimensional data structure that can store various type of data, including character, numeric (i.e., integer, floating point), and many more. The following code creates a DataFrame of three columns with label `Name`, `Age`, and `Score` from a dictionary called `data`.

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 35, 20, 28],
    'Score': [85, 90, 88, 76, 95]
}

df = pd.DataFrame(data)
df.head()
# Out:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   35     88
# 3    David   20     76
# 4      Eva   28     95

# %% [markdown]
# ## 📁 Reading and Writing CSV Files

# %%
# Write to CSV
df.to_csv('../dataset/sample_data.csv', index=False)

# %%
# Read the existing CSV file
transactionDf = pd.read_csv('../dataset/sample_customer_transactions.csv')
transactionDf.head()
# Out:
#   transaction_id transaction_date customer_id product_id        product_name  \
# 0          T0001       2024-08-13       C4310       P117  Beverage Product 6
# 1          T0002       2024-11-22       C6417       P749   Canned Product 11
# 2          T0003       2024-10-28       C3303       P640  Beverage Product 3
# 3          T0004       2024-10-16       C7175       P126    Canned Product 3
# 4          T0005       2024-03-30       C4760       P730   Canned Product 14
#
#    category  quantity  unit_price store_location payment_method  \
# 0  beverage         5       17.94       New York           cash
# 1    canned        10        7.04        Houston    credit card
# 2  beverage         1       14.19        Chicago           cash
# 3    canned         6        1.51        Chicago         online
# 4    canned         2       13.97        Phoenix           cash
#
#     delivery_method  discount_applied  demand_type order_status  \
# 0     home delivery              3.64     seasonal    cancelled
# 1            pickup              1.67  promotional    completed
# 2  digital download              2.32     seasonal    completed
# 3     home delivery              0.28  promotional      pending
# 4     home delivery              4.17      regular    completed
#
#    customer_rating
# 0                4
# 1                5
# 2                2
# 3                4
# 4                4

# %% [markdown]
# ## 🔍 Basic Information and Statistical Summary

# %%
# Display basic info
transactionDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    50 non-null     object
#  1   transaction_date  50 non-null     object
#  2   customer_id       50 non-null     object
#  3   product_id        50 non-null     object
#  4   product_name      50 non-null     object
#  5   category          50 non-null     object
#  6   quantity          50 non-null     int64
#  7   unit_price        50 non-null     float64
#  8   store_location    50 non-null     object
#  9   payment_method    50 non-null     object
#  10  delivery_method   50 non-null     object
#  11  discount_applied  50 non-null     float64
#  12  demand_type       50 non-null     object
#  13  order_status      50 non-null     object
#  14  customer_rating   50 non-null     int64
# dtypes: float64(2), int64(2), object(11)
# memory usage: 6.0+ KB

# %%
# shows statistical summary of numeric columns
transactionDf.describe()
# Out:
#         quantity  unit_price  discount_applied  customer_rating
# count  50.000000   50.000000         50.000000         50.00000
# mean    5.440000   10.824600          2.655000          3.24000
# std     2.785971    5.255466          1.337725          1.34862
# min     1.000000    1.510000          0.280000          1.00000
# 25%     3.000000    6.405000          1.542500          2.00000
# 50%     5.500000   11.635000          2.940000          3.00000
# 75%     8.000000   15.090000          3.897500          4.00000
# max    10.000000   19.620000          4.780000          5.00000

# %%
# shows skewness of numeric columns
transactionDf.select_dtypes(include=['number']).skew()
# Out:
# quantity           -0.057297
# unit_price         -0.046861
# discount_applied   -0.309945
# customer_rating    -0.250106
# dtype: float64

# %% [markdown]
# ## 🛠️ Modify Columns: Rename, Drop, Add
# Any modifications made in a DataFrame object will not change the original `csv` file. Change will be applied once the DataFrame is overwritten the `csv` file through executing `to_csv` function.

# %%
# Rename column 'discount_applied' to 'discount_used'
transactionDf.rename(columns={'discount_applied': 'discount_used'}, inplace=True)

transactionDf.head()
# Out:
#   transaction_id transaction_date customer_id product_id        product_name  \
# 0          T0001       2024-08-13       C4310       P117  Beverage Product 6
# 1          T0002       2024-11-22       C6417       P749   Canned Product 11
# 2          T0003       2024-10-28       C3303       P640  Beverage Product 3
# 3          T0004       2024-10-16       C7175       P126    Canned Product 3
# 4          T0005       2024-03-30       C4760       P730   Canned Product 14
#
#    category  quantity  unit_price store_location payment_method  \
# 0  beverage         5       17.94       New York           cash
# 1    canned        10        7.04        Houston    credit card
# 2  beverage         1       14.19        Chicago           cash
# 3    canned         6        1.51        Chicago         online
# 4    canned         2       13.97        Phoenix           cash
#
#     delivery_method  discount_used  demand_type order_status  customer_rating
# 0     home delivery           3.64     seasonal    cancelled                4
# 1            pickup           1.67  promotional    completed                5
# 2  digital download           2.32     seasonal    completed                2
# 3     home delivery           0.28  promotional      pending                4
# 4     home delivery           4.17      regular    completed                4

# %%
## add a new column 'expensive' containing True or False value corresponds to unit_price
transactionDf['expensive'] = transactionDf['unit_price'] > 11 
transactionDf.head()
# Out:
#   transaction_id transaction_date customer_id product_id        product_name  \
# 0          T0001       2024-08-13       C4310       P117  Beverage Product 6
# 1          T0002       2024-11-22       C6417       P749   Canned Product 11
# 2          T0003       2024-10-28       C3303       P640  Beverage Product 3
# 3          T0004       2024-10-16       C7175       P126    Canned Product 3
# 4          T0005       2024-03-30       C4760       P730   Canned Product 14
#
#    category  quantity  unit_price store_location payment_method  \
# 0  beverage         5       17.94       New York           cash
# 1    canned        10        7.04        Houston    credit card
# 2  beverage         1       14.19        Chicago           cash
# 3    canned         6        1.51        Chicago         online
# 4    canned         2       13.97        Phoenix           cash
#
#     delivery_method  discount_used  demand_type order_status  customer_rating  \
# 0     home delivery           3.64     seasonal    cancelled                4
# 1            pickup           1.67  promotional    completed                5
# 2  digital download           2.32     seasonal    completed                2
# 3     home delivery           0.28  promotional      pending                4
# 4     home delivery           4.17      regular    completed                4
#
#    expensive
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True

# %% [markdown]
# The following code aims at adding new columns `total_price` and `price_after_discount`. DataFrame allows for using calculation across columns.
#
# $price\_after\_discount = total\_price - (total\_price * discount\_used/100)$
#
# The `round` function adjust the floating point of decimal values.

# %%
# Add a new column 'total_price' and 'price_after_discount'
transactionDf['total_price'] = transactionDf['quantity'] * transactionDf['unit_price']
transactionDf['price_after_discount'] = round(transactionDf['total_price'] - (transactionDf['total_price'] * transactionDf['discount_used']/100), 2)
transactionDf.head()
# Out:
#   transaction_id transaction_date customer_id product_id        product_name  \
# 0          T0001       2024-08-13       C4310       P117  Beverage Product 6
# 1          T0002       2024-11-22       C6417       P749   Canned Product 11
# 2          T0003       2024-10-28       C3303       P640  Beverage Product 3
# 3          T0004       2024-10-16       C7175       P126    Canned Product 3
# 4          T0005       2024-03-30       C4760       P730   Canned Product 14
#
#    category  quantity  unit_price store_location payment_method  \
# 0  beverage         5       17.94       New York           cash
# 1    canned        10        7.04        Houston    credit card
# 2  beverage         1       14.19        Chicago           cash
# 3    canned         6        1.51        Chicago         online
# 4    canned         2       13.97        Phoenix           cash
#
#     delivery_method  discount_used  demand_type order_status  customer_rating  \
# 0     home delivery           3.64     seasonal    cancelled                4
# 1            pickup           1.67  promotional    completed                5
# 2  digital download           2.32     seasonal    completed                2
# 3     home delivery           0.28  promotional      pending                4
# 4     home delivery           4.17      regular    completed                4
#
#    expensive  total_price  price_after_discount
# 0       True        89.70                 86.43
# 1      False        70.40                 69.22
# 2       True        14.19                 13.86
# 3      False         9.06                  9.03
# 4       True        27.94                 26.77

# %%
# Drop the 'expensive' column
transactionDf.drop(columns=['expensive'], inplace=True)
transactionDf.head()
# Out:
#   transaction_id transaction_date customer_id product_id        product_name  \
# 0          T0001       2024-08-13       C4310       P117  Beverage Product 6
# 1          T0002       2024-11-22       C6417       P749   Canned Product 11
# 2          T0003       2024-10-28       C3303       P640  Beverage Product 3
# 3          T0004       2024-10-16       C7175       P126    Canned Product 3
# 4          T0005       2024-03-30       C4760       P730   Canned Product 14
#
#    category  quantity  unit_price store_location payment_method  \
# 0  beverage         5       17.94       New York           cash
# 1    canned        10        7.04        Houston    credit card
# 2  beverage         1       14.19        Chicago           cash
# 3    canned         6        1.51        Chicago         online
# 4    canned         2       13.97        Phoenix           cash
#
#     delivery_method  discount_used  demand_type order_status  customer_rating  \
# 0     home delivery           3.64     seasonal    cancelled                4
# 1            pickup           1.67  promotional    completed                5
# 2  digital download           2.32     seasonal    completed                2
# 3     home delivery           0.28  promotional      pending                4
# 4     home delivery           4.17      regular    completed                4
#
#    total_price  price_after_discount
# 0        89.70                 86.43
# 1        70.40                 69.22
# 2        14.19                 13.86
# 3         9.06                  9.03
# 4        27.94                 26.77

# %% [markdown]
# ## 📝 Data Cleaning

# %%
# check for null values
transactionDf.isnull().sum()
# Out:
# transaction_id          0
# transaction_date        0
# customer_id             0
# product_id              0
# product_name            0
# category                0
# quantity                0
# unit_price              0
# store_location          0
# payment_method          0
# delivery_method         0
# discount_used           0
# demand_type             0
# order_status            0
# customer_rating         0
# total_price             0
# price_after_discount    0
# dtype: int64

# %%
# check for NA values
transactionDf.isna().sum()
# Out:
# transaction_id          0
# transaction_date        0
# customer_id             0
# product_id              0
# product_name            0
# category                0
# quantity                0
# unit_price              0
# store_location          0
# payment_method          0
# delivery_method         0
# discount_used           0
# demand_type             0
# order_status            0
# customer_rating         0
# total_price             0
# price_after_discount    0
# dtype: int64

# %%
# check for duplicate values
transactionDf.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check for unique values
transactionDf.nunique()
# Out:
# transaction_id          50
# transaction_date        46
# customer_id             50
# product_id              49
# product_name            42
# category                 5
# quantity                10
# unit_price              49
# store_location           5
# payment_method           3
# delivery_method          3
# discount_used           47
# demand_type              3
# order_status             3
# customer_rating          5
# total_price             50
# price_after_discount    50
# dtype: int64

# %% [markdown]
# You can run the following code to
#
# * drop all rows containing null values
#
# ```python
# df.dropna()
# ```
#
# * drop all columns containing null values
# ```python
# df.dropna(axis=1)
# ```
#
# * replace null values with `100`
# ```python
# df.fillna(100)
# ```
#
# * replace null values of column `category` with `Beverage`
# ```python
# df['category'].fillna('Beverage')
# ```
#
# * replace null values of column `unit_price` with mean value
# ```python
# df['unit_price'].fillna(df['unit_price'].mean())
# ```

# %% [markdown]
# ## 🔃 Sorting Columns
# ### Sort one column

# %%
# Sort by quantity descending
transactionDf.sort_values(by='quantity', ascending=False)
# Out:
#    transaction_id transaction_date customer_id product_id  \
# 1           T0002       2024-11-22       C6417       P749
# 14          T0015       2024-02-14       C1651       P874
# 15          T0016       2024-11-01       C9950       P867
# 38          T0039       2024-07-14       C5400       P411
# 13          T0014       2024-01-22       C6004       P732
# 6           T0007       2024-05-27       C5791       P523
# 49          T0050       2024-11-07       C9997       P268
# 25          T0026       2024-08-19       C2206       P673
# 9           T0010       2024-09-17       C1560       P143
# 16          T0017       2024-09-18       C1143       P409
# 30          T0031       2024-09-05       C5413       P459
# 36          T0037       2024-05-27       C6386       P547
# 41          T0042       2024-08-02       C3536       P812
# 35          T0036       2024-12-01       C3422       P257
# 23          T0024       2024-09-22       C7836       P124
# 5           T0006       2024-03-11       C2428       P179
# 43          T0044       2024-10-03       C8021       P214
# 47          T0048       2024-11-17       C1618       P391
# 33          T0034       2024-02-18       C8392       P583
# 19          T0020       2024-03-23       C8152       P329
# 40          T0041       2024-11-17       C1737       P879
# 10          T0011       2024-01-25       C5446       P118
# 3           T0004       2024-10-16       C7175       P126
# 42          T0043       2024-12-27       C9666       P986
# 17          T0018       2024-02-26       C1983       P835
# 0           T0001       2024-08-13       C4310       P117
# 34          T0035       2024-11-09       C4609       P614
# 48          T0049       2024-12-17       C2410       P139
# 29          T0030       2024-04-01       C4962       P195
# 27          T0028       2024-09-20       C4341       P103
# 45          T0046       2024-07-16       C3608       P492
# 12          T0013       2024-10-28       C1505       P131
# 18          T0019       2024-05-12       C3221       P481
# 37          T0038       2024-09-11       C4242       P486
# 28          T0029       2024-07-12       C5972       P759
# 31          T0032       2024-08-23       C5850       P404
# 22          T0023       2024-02-13       C9908       P476
# 21          T0022       2024-05-16       C3237       P867
# 7           T0008       2024-09-02       C5584       P303
# 46          T0047       2024-10-07       C8504       P101
# 24          T0025       2024-11-22       C3849       P229
# 4           T0005       2024-03-30       C4760       P730
# 39          T0040       2024-06-22       C3967       P695
# 32          T0033       2024-04-25       C9242       P724
# 26          T0027       2024-05-22       C6694       P247
# 2           T0003       2024-10-28       C3303       P640
# 11          T0012       2024-10-06       C9638       P517
# 8           T0009       2024-04-15       C3174       P395
# 20          T0021       2024-03-26       C9515       P352
# 44          T0045       2024-05-07       C5406       P373
#
#            product_name  category  quantity  unit_price store_location  \
# 1     Canned Product 11    canned        10        7.04        Houston
# 14     Snacks Product 4    snacks        10       19.62       New York
# 15    Canned Product 12    canned        10        5.52    Los Angeles
# 38    Frozen Product 13    frozen        10       12.19        Phoenix
# 13    Snacks Product 17    snacks         9        6.99       New York
# 6       Dairy Product 3     dairy         9       13.20       New York
# 49    Frozen Product 18    frozen         9       14.19        Chicago
# 25   Beverage Product 2  beverage         8       19.20        Phoenix
# 9     Frozen Product 14    frozen         8       15.36        Chicago
# 16     Canned Product 3    canned         8       16.48    Los Angeles
# 30     Dairy Product 16     dairy         8       18.65    Los Angeles
# 36     Dairy Product 18     dairy         8        8.09       New York
# 41     Dairy Product 18     dairy         8       11.64        Phoenix
# 35    Snacks Product 12    snacks         8        8.89        Houston
# 23    Canned Product 12    canned         7        7.35        Chicago
# 5    Beverage Product 9  beverage         7        4.79    Los Angeles
# 43    Canned Product 15    canned         7       11.87       New York
# 47  Beverage Product 19  beverage         7        5.13        Chicago
# 33    Frozen Product 12    frozen         7       11.02        Chicago
# 19     Dairy Product 11     dairy         7        4.60        Phoenix
# 40     Dairy Product 17     dairy         7        7.27    Los Angeles
# 10     Canned Product 7    canned         6        5.55        Houston
# 3      Canned Product 3    canned         6        1.51        Chicago
# 42     Frozen Product 1    frozen         6       14.28        Phoenix
# 17     Snacks Product 5    snacks         6       17.36        Houston
# 0    Beverage Product 6  beverage         5       17.94       New York
# 34     Canned Product 9    canned         5       11.63        Chicago
# 48     Dairy Product 19     dairy         5       18.83    Los Angeles
# 29   Beverage Product 1  beverage         5        3.43        Chicago
# 27     Snacks Product 9    snacks         5       15.82    Los Angeles
# 45     Canned Product 3    canned         4       15.69        Phoenix
# 12     Frozen Product 8    frozen         4       18.36        Phoenix
# 18  Beverage Product 10  beverage         4        2.73       New York
# 37  Beverage Product 11  beverage         4       11.84       New York
# 28   Beverage Product 4  beverage         4       17.16        Houston
# 31     Dairy Product 12     dairy         4        7.26        Chicago
# 22     Dairy Product 11     dairy         3        6.06    Los Angeles
# 21     Dairy Product 16     dairy         3       10.21    Los Angeles
# 7      Snacks Product 7    snacks         3        2.59        Chicago
# 46    Snacks Product 18    snacks         3        1.89        Houston
# 24    Frozen Product 11    frozen         2        6.21       New York
# 4     Canned Product 14    canned         2       13.97        Phoenix
# 39      Dairy Product 7     dairy         2       13.67    Los Angeles
# 32    Canned Product 17    canned         2       15.84    Los Angeles
# 26   Beverage Product 2  beverage         2       13.30       New York
# 2    Beverage Product 3  beverage         1       14.19        Chicago
# 11    Canned Product 16    canned         1       10.96        Phoenix
# 8      Frozen Product 6    frozen         1        4.23    Los Angeles
# 20     Snacks Product 9    snacks         1       11.88    Los Angeles
# 44     Snacks Product 1    snacks         1        7.75        Houston
#
#    payment_method   delivery_method  discount_used  demand_type order_status  \
# 1     credit card            pickup           1.67  promotional    completed
# 14           cash            pickup           3.06  promotional      pending
# 15         online            pickup           3.23     seasonal    completed
# 38         online            pickup           1.31      regular    cancelled
# 13         online     home delivery           3.86     seasonal    cancelled
# 6          online  digital download           2.86      regular    cancelled
# 49         online     home delivery           4.78      regular    cancelled
# 25           cash     home delivery           2.37     seasonal    cancelled
# 9          online            pickup           2.89     seasonal    cancelled
# 16    credit card  digital download           1.31     seasonal    cancelled
# 30         online  digital download           1.94      regular    completed
# 36           cash     home delivery           0.63      regular    cancelled
# 41         online  digital download           3.22  promotional      pending
# 35    credit card            pickup           0.72      regular      pending
# 23           cash            pickup           4.34  promotional    cancelled
# 5            cash            pickup           4.60     seasonal      pending
# 43           cash            pickup           0.49     seasonal      pending
# 47    credit card            pickup           3.97     seasonal      pending
# 33    credit card  digital download           0.33  promotional      pending
# 19           cash  digital download           3.77  promotional      pending
# 40    credit card  digital download           4.09  promotional    cancelled
# 10    credit card            pickup           2.99     seasonal    cancelled
# 3          online     home delivery           0.28  promotional      pending
# 42    credit card     home delivery           2.03  promotional    completed
# 17           cash     home delivery           4.01     seasonal    completed
# 0            cash     home delivery           3.64     seasonal    cancelled
# 34         online     home delivery           1.79      regular    cancelled
# 48         online  digital download           1.88      regular    completed
# 29           cash  digital download           0.62     seasonal    cancelled
# 27           cash  digital download           0.50     seasonal    completed
# 45         online  digital download           2.44  promotional      pending
# 12    credit card     home delivery           3.19      regular    cancelled
# 18           cash     home delivery           2.87     seasonal      pending
# 37         online     home delivery           0.81     seasonal      pending
# 28           cash            pickup           3.27      regular    cancelled
# 31    credit card     home delivery           4.55      regular      pending
# 22           cash  digital download           3.97      regular    cancelled
# 21           cash  digital download           4.15      regular      pending
# 7     credit card  digital download           1.50  promotional      pending
# 46    credit card     home delivery           3.50     seasonal      pending
# 24         online  digital download           3.91     seasonal    completed
# 4            cash     home delivery           4.17      regular    completed
# 39         online  digital download           1.12  promotional    completed
# 32         online  digital download           1.08      regular    completed
# 26    credit card  digital download           4.07  promotional    cancelled
# 2            cash  digital download           2.32     seasonal    completed
# 11         online     home delivery           3.94     seasonal      pending
# 8            cash  digital download           3.22     seasonal    completed
# 20           cash            pickup           3.18      regular    cancelled
# 44         online            pickup           2.31     seasonal      pending
#
#     customer_rating  total_price  price_after_discount
# 1                 5        70.40                 69.22
# 14                4       196.20                190.20
# 15                3        55.20                 53.42
# 38                3       121.90                120.30
# 13                2        62.91                 60.48
# 6                 5       118.80                115.40
# 49                3       127.71                121.61
# 25                1       153.60                149.96
# 9                 5       122.88                119.33
# 16                3       131.84                130.11
# 30                3       149.20                146.31
# 36                1        64.72                 64.31
# 41                1        93.12                 90.12
# 35                5        71.12                 70.61
# 23                2        51.45                 49.22
# 5                 4        33.53                 31.99
# 43                1        83.09                 82.68
# 47                5        35.91                 34.48
# 33                5        77.14                 76.89
# 19                2        32.20                 30.99
# 40                4        50.89                 48.81
# 10                4        33.30                 32.30
# 3                 4         9.06                  9.03
# 42                4        85.68                 83.94
# 17                1       104.16                 99.98
# 0                 4        89.70                 86.43
# 34                4        58.15                 57.11
# 48                2        94.15                 92.38
# 29                3        17.15                 17.04
# 27                3        79.10                 78.70
# 45                1        62.76                 61.23
# 12                2        73.44                 71.10
# 18                3        10.92                 10.61
# 37                4        47.36                 46.98
# 28                3        68.64                 66.40
# 31                3        29.04                 27.72
# 22                3        18.18                 17.46
# 21                5        30.63                 29.36
# 7                 1         7.77                  7.65
# 46                2         5.67                  5.47
# 24                4        12.42                 11.93
# 4                 4        27.94                 26.77
# 39                5        27.34                 27.03
# 32                5        31.68                 31.34
# 26                3        26.60                 25.52
# 2                 2        14.19                 13.86
# 11                5        10.96                 10.53
# 8                 4         4.23                  4.09
# 20                5        11.88                 11.50
# 44                2         7.75                  7.57

# %% [markdown]
# ### Sort multiple columns

# %%
# Sort by quantity descending and unit_price ascending
transactionDf.sort_values(['quantity', 'unit_price'], ascending=[False, True])
# Out:
#    transaction_id transaction_date customer_id product_id  \
# 15          T0016       2024-11-01       C9950       P867
# 1           T0002       2024-11-22       C6417       P749
# 38          T0039       2024-07-14       C5400       P411
# 14          T0015       2024-02-14       C1651       P874
# 13          T0014       2024-01-22       C6004       P732
# 6           T0007       2024-05-27       C5791       P523
# 49          T0050       2024-11-07       C9997       P268
# 36          T0037       2024-05-27       C6386       P547
# 35          T0036       2024-12-01       C3422       P257
# 41          T0042       2024-08-02       C3536       P812
# 9           T0010       2024-09-17       C1560       P143
# 16          T0017       2024-09-18       C1143       P409
# 30          T0031       2024-09-05       C5413       P459
# 25          T0026       2024-08-19       C2206       P673
# 19          T0020       2024-03-23       C8152       P329
# 5           T0006       2024-03-11       C2428       P179
# 47          T0048       2024-11-17       C1618       P391
# 40          T0041       2024-11-17       C1737       P879
# 23          T0024       2024-09-22       C7836       P124
# 33          T0034       2024-02-18       C8392       P583
# 43          T0044       2024-10-03       C8021       P214
# 3           T0004       2024-10-16       C7175       P126
# 10          T0011       2024-01-25       C5446       P118
# 42          T0043       2024-12-27       C9666       P986
# 17          T0018       2024-02-26       C1983       P835
# 29          T0030       2024-04-01       C4962       P195
# 34          T0035       2024-11-09       C4609       P614
# 27          T0028       2024-09-20       C4341       P103
# 0           T0001       2024-08-13       C4310       P117
# 48          T0049       2024-12-17       C2410       P139
# 18          T0019       2024-05-12       C3221       P481
# 31          T0032       2024-08-23       C5850       P404
# 37          T0038       2024-09-11       C4242       P486
# 45          T0046       2024-07-16       C3608       P492
# 28          T0029       2024-07-12       C5972       P759
# 12          T0013       2024-10-28       C1505       P131
# 46          T0047       2024-10-07       C8504       P101
# 7           T0008       2024-09-02       C5584       P303
# 22          T0023       2024-02-13       C9908       P476
# 21          T0022       2024-05-16       C3237       P867
# 24          T0025       2024-11-22       C3849       P229
# 26          T0027       2024-05-22       C6694       P247
# 39          T0040       2024-06-22       C3967       P695
# 4           T0005       2024-03-30       C4760       P730
# 32          T0033       2024-04-25       C9242       P724
# 8           T0009       2024-04-15       C3174       P395
# 44          T0045       2024-05-07       C5406       P373
# 11          T0012       2024-10-06       C9638       P517
# 20          T0021       2024-03-26       C9515       P352
# 2           T0003       2024-10-28       C3303       P640
#
#            product_name  category  quantity  unit_price store_location  \
# 15    Canned Product 12    canned        10        5.52    Los Angeles
# 1     Canned Product 11    canned        10        7.04        Houston
# 38    Frozen Product 13    frozen        10       12.19        Phoenix
# 14     Snacks Product 4    snacks        10       19.62       New York
# 13    Snacks Product 17    snacks         9        6.99       New York
# 6       Dairy Product 3     dairy         9       13.20       New York
# 49    Frozen Product 18    frozen         9       14.19        Chicago
# 36     Dairy Product 18     dairy         8        8.09       New York
# 35    Snacks Product 12    snacks         8        8.89        Houston
# 41     Dairy Product 18     dairy         8       11.64        Phoenix
# 9     Frozen Product 14    frozen         8       15.36        Chicago
# 16     Canned Product 3    canned         8       16.48    Los Angeles
# 30     Dairy Product 16     dairy         8       18.65    Los Angeles
# 25   Beverage Product 2  beverage         8       19.20        Phoenix
# 19     Dairy Product 11     dairy         7        4.60        Phoenix
# 5    Beverage Product 9  beverage         7        4.79    Los Angeles
# 47  Beverage Product 19  beverage         7        5.13        Chicago
# 40     Dairy Product 17     dairy         7        7.27    Los Angeles
# 23    Canned Product 12    canned         7        7.35        Chicago
# 33    Frozen Product 12    frozen         7       11.02        Chicago
# 43    Canned Product 15    canned         7       11.87       New York
# 3      Canned Product 3    canned         6        1.51        Chicago
# 10     Canned Product 7    canned         6        5.55        Houston
# 42     Frozen Product 1    frozen         6       14.28        Phoenix
# 17     Snacks Product 5    snacks         6       17.36        Houston
# 29   Beverage Product 1  beverage         5        3.43        Chicago
# 34     Canned Product 9    canned         5       11.63        Chicago
# 27     Snacks Product 9    snacks         5       15.82    Los Angeles
# 0    Beverage Product 6  beverage         5       17.94       New York
# 48     Dairy Product 19     dairy         5       18.83    Los Angeles
# 18  Beverage Product 10  beverage         4        2.73       New York
# 31     Dairy Product 12     dairy         4        7.26        Chicago
# 37  Beverage Product 11  beverage         4       11.84       New York
# 45     Canned Product 3    canned         4       15.69        Phoenix
# 28   Beverage Product 4  beverage         4       17.16        Houston
# 12     Frozen Product 8    frozen         4       18.36        Phoenix
# 46    Snacks Product 18    snacks         3        1.89        Houston
# 7      Snacks Product 7    snacks         3        2.59        Chicago
# 22     Dairy Product 11     dairy         3        6.06    Los Angeles
# 21     Dairy Product 16     dairy         3       10.21    Los Angeles
# 24    Frozen Product 11    frozen         2        6.21       New York
# 26   Beverage Product 2  beverage         2       13.30       New York
# 39      Dairy Product 7     dairy         2       13.67    Los Angeles
# 4     Canned Product 14    canned         2       13.97        Phoenix
# 32    Canned Product 17    canned         2       15.84    Los Angeles
# 8      Frozen Product 6    frozen         1        4.23    Los Angeles
# 44     Snacks Product 1    snacks         1        7.75        Houston
# 11    Canned Product 16    canned         1       10.96        Phoenix
# 20     Snacks Product 9    snacks         1       11.88    Los Angeles
# 2    Beverage Product 3  beverage         1       14.19        Chicago
#
#    payment_method   delivery_method  discount_used  demand_type order_status  \
# 15         online            pickup           3.23     seasonal    completed
# 1     credit card            pickup           1.67  promotional    completed
# 38         online            pickup           1.31      regular    cancelled
# 14           cash            pickup           3.06  promotional      pending
# 13         online     home delivery           3.86     seasonal    cancelled
# 6          online  digital download           2.86      regular    cancelled
# 49         online     home delivery           4.78      regular    cancelled
# 36           cash     home delivery           0.63      regular    cancelled
# 35    credit card            pickup           0.72      regular      pending
# 41         online  digital download           3.22  promotional      pending
# 9          online            pickup           2.89     seasonal    cancelled
# 16    credit card  digital download           1.31     seasonal    cancelled
# 30         online  digital download           1.94      regular    completed
# 25           cash     home delivery           2.37     seasonal    cancelled
# 19           cash  digital download           3.77  promotional      pending
# 5            cash            pickup           4.60     seasonal      pending
# 47    credit card            pickup           3.97     seasonal      pending
# 40    credit card  digital download           4.09  promotional    cancelled
# 23           cash            pickup           4.34  promotional    cancelled
# 33    credit card  digital download           0.33  promotional      pending
# 43           cash            pickup           0.49     seasonal      pending
# 3          online     home delivery           0.28  promotional      pending
# 10    credit card            pickup           2.99     seasonal    cancelled
# 42    credit card     home delivery           2.03  promotional    completed
# 17           cash     home delivery           4.01     seasonal    completed
# 29           cash  digital download           0.62     seasonal    cancelled
# 34         online     home delivery           1.79      regular    cancelled
# 27           cash  digital download           0.50     seasonal    completed
# 0            cash     home delivery           3.64     seasonal    cancelled
# 48         online  digital download           1.88      regular    completed
# 18           cash     home delivery           2.87     seasonal      pending
# 31    credit card     home delivery           4.55      regular      pending
# 37         online     home delivery           0.81     seasonal      pending
# 45         online  digital download           2.44  promotional      pending
# 28           cash            pickup           3.27      regular    cancelled
# 12    credit card     home delivery           3.19      regular    cancelled
# 46    credit card     home delivery           3.50     seasonal      pending
# 7     credit card  digital download           1.50  promotional      pending
# 22           cash  digital download           3.97      regular    cancelled
# 21           cash  digital download           4.15      regular      pending
# 24         online  digital download           3.91     seasonal    completed
# 26    credit card  digital download           4.07  promotional    cancelled
# 39         online  digital download           1.12  promotional    completed
# 4            cash     home delivery           4.17      regular    completed
# 32         online  digital download           1.08      regular    completed
# 8            cash  digital download           3.22     seasonal    completed
# 44         online            pickup           2.31     seasonal      pending
# 11         online     home delivery           3.94     seasonal      pending
# 20           cash            pickup           3.18      regular    cancelled
# 2            cash  digital download           2.32     seasonal    completed
#
#     customer_rating  total_price  price_after_discount
# 15                3        55.20                 53.42
# 1                 5        70.40                 69.22
# 38                3       121.90                120.30
# 14                4       196.20                190.20
# 13                2        62.91                 60.48
# 6                 5       118.80                115.40
# 49                3       127.71                121.61
# 36                1        64.72                 64.31
# 35                5        71.12                 70.61
# 41                1        93.12                 90.12
# 9                 5       122.88                119.33
# 16                3       131.84                130.11
# 30                3       149.20                146.31
# 25                1       153.60                149.96
# 19                2        32.20                 30.99
# 5                 4        33.53                 31.99
# 47                5        35.91                 34.48
# 40                4        50.89                 48.81
# 23                2        51.45                 49.22
# 33                5        77.14                 76.89
# 43                1        83.09                 82.68
# 3                 4         9.06                  9.03
# 10                4        33.30                 32.30
# 42                4        85.68                 83.94
# 17                1       104.16                 99.98
# 29                3        17.15                 17.04
# 34                4        58.15                 57.11
# 27                3        79.10                 78.70
# 0                 4        89.70                 86.43
# 48                2        94.15                 92.38
# 18                3        10.92                 10.61
# 31                3        29.04                 27.72
# 37                4        47.36                 46.98
# 45                1        62.76                 61.23
# 28                3        68.64                 66.40
# 12                2        73.44                 71.10
# 46                2         5.67                  5.47
# 7                 1         7.77                  7.65
# 22                3        18.18                 17.46
# 21                5        30.63                 29.36
# 24                4        12.42                 11.93
# 26                3        26.60                 25.52
# 39                5        27.34                 27.03
# 4                 4        27.94                 26.77
# 32                5        31.68                 31.34
# 8                 4         4.23                  4.09
# 44                2         7.75                  7.57
# 11                5        10.96                 10.53
# 20                5        11.88                 11.50
# 2                 2        14.19                 13.86

# %% [markdown]
# ## 🔍 Filtering

# %%
# Filter transaction with quantity > 5 and unit_price <= 10
transactionDf[(transactionDf['quantity'] > 5) & (transactionDf['unit_price'] <= 10)]
# Out:
#    transaction_id transaction_date customer_id product_id  \
# 1           T0002       2024-11-22       C6417       P749
# 3           T0004       2024-10-16       C7175       P126
# 5           T0006       2024-03-11       C2428       P179
# 10          T0011       2024-01-25       C5446       P118
# 13          T0014       2024-01-22       C6004       P732
# 15          T0016       2024-11-01       C9950       P867
# 19          T0020       2024-03-23       C8152       P329
# 23          T0024       2024-09-22       C7836       P124
# 35          T0036       2024-12-01       C3422       P257
# 36          T0037       2024-05-27       C6386       P547
# 40          T0041       2024-11-17       C1737       P879
# 47          T0048       2024-11-17       C1618       P391
#
#            product_name  category  quantity  unit_price store_location  \
# 1     Canned Product 11    canned        10        7.04        Houston
# 3      Canned Product 3    canned         6        1.51        Chicago
# 5    Beverage Product 9  beverage         7        4.79    Los Angeles
# 10     Canned Product 7    canned         6        5.55        Houston
# 13    Snacks Product 17    snacks         9        6.99       New York
# 15    Canned Product 12    canned        10        5.52    Los Angeles
# 19     Dairy Product 11     dairy         7        4.60        Phoenix
# 23    Canned Product 12    canned         7        7.35        Chicago
# 35    Snacks Product 12    snacks         8        8.89        Houston
# 36     Dairy Product 18     dairy         8        8.09       New York
# 40     Dairy Product 17     dairy         7        7.27    Los Angeles
# 47  Beverage Product 19  beverage         7        5.13        Chicago
#
#    payment_method   delivery_method  discount_used  demand_type order_status  \
# 1     credit card            pickup           1.67  promotional    completed
# 3          online     home delivery           0.28  promotional      pending
# 5            cash            pickup           4.60     seasonal      pending
# 10    credit card            pickup           2.99     seasonal    cancelled
# 13         online     home delivery           3.86     seasonal    cancelled
# 15         online            pickup           3.23     seasonal    completed
# 19           cash  digital download           3.77  promotional      pending
# 23           cash            pickup           4.34  promotional    cancelled
# 35    credit card            pickup           0.72      regular      pending
# 36           cash     home delivery           0.63      regular    cancelled
# 40    credit card  digital download           4.09  promotional    cancelled
# 47    credit card            pickup           3.97     seasonal      pending
#
#     customer_rating  total_price  price_after_discount
# 1                 5        70.40                 69.22
# 3                 4         9.06                  9.03
# 5                 4        33.53                 31.99
# 10                4        33.30                 32.30
# 13                2        62.91                 60.48
# 15                3        55.20                 53.42
# 19                2        32.20                 30.99
# 23                2        51.45                 49.22
# 35                5        71.12                 70.61
# 36                1        64.72                 64.31
# 40                4        50.89                 48.81
# 47                5        35.91                 34.48

# %% [markdown]
# ## 📊 Grouping and Aggregation

# %%
transactionDf.groupby('category')['quantity'].agg(['mean', 'max', 'min'])
# Out:
#               mean  max  min
# category
# beverage  4.700000    8    1
# canned    5.666667   10    1
# dairy     5.818182    9    2
# frozen    5.875000   10    1
# snacks    5.111111   10    1

# %%
# multiple columns aggregation
transactionDf.groupby('category').agg({'total_price': ['mean', 'max', 'min'],'customer_rating': 'mean'})
# Out:
#          total_price                customer_rating
#                 mean     max    min            mean
# category
# beverage   49.760000  153.60  10.92        3.200000
# canned     52.152500  131.84   9.06        3.416667
# dairy      64.388182  149.20  18.18        3.090909
# frozen     78.175000  127.71   4.23        3.750000
# snacks     60.728889  196.20   5.67        2.777778

# %%
# multiple columns grouping and aggregation
transactionDf.groupby(['store_location','category']).agg({'total_price': ['count','mean', 'max', 'min'],
                                                          'discount_used': ['mean', 'std'],
                                                          'customer_rating': 'mean'})
# Out:
#                         total_price                             discount_used  \
#                               count        mean     max     min          mean
# store_location category
# Chicago        beverage           3   22.416667   35.91   14.19      2.303333
#                canned             3   39.553333   58.15    9.06      2.136667
#                dairy              1   29.040000   29.04   29.04      4.550000
#                frozen             3  109.243333  127.71   77.14      2.666667
#                snacks             1    7.770000    7.77    7.77      1.500000
# Houston        beverage           1   68.640000   68.64   68.64      3.270000
#                canned             2   51.850000   70.40   33.30      2.330000
#                snacks             4   47.175000  104.16    5.67      2.635000
# Los Angeles    beverage           1   33.530000   33.53   33.53      4.600000
#                canned             3   72.906667  131.84   31.68      1.873333
#                dairy              6   61.731667  149.20   18.18      2.858333
#                frozen             1    4.230000    4.23    4.23      3.220000
#                snacks             2   45.490000   79.10   11.88      1.840000
# New York       beverage           4   43.645000   89.70   10.92      2.847500
#                canned             1   83.090000   83.09   83.09      0.490000
#                dairy              2   91.760000  118.80   64.72      1.745000
#                frozen             1   12.420000   12.42   12.42      3.910000
#                snacks             2  129.555000  196.20   62.91      3.460000
# Phoenix        beverage           1  153.600000  153.60  153.60      2.370000
#                canned             3   33.886667   62.76   10.96      3.516667
#                dairy              2   62.660000   93.12   32.20      3.495000
#                frozen             3   93.673333  121.90   73.44      2.176667
#
#                                   customer_rating
#                               std            mean
# store_location category
# Chicago        beverage  1.675062        3.333333
#                canned    2.052080        3.333333
#                dairy          NaN        3.000000
#                frozen    2.233391        4.333333
#                snacks         NaN        1.000000
# Houston        beverage       NaN        3.000000
#                canned    0.933381        4.500000
#                snacks    1.461928        2.500000
# Los Angeles    beverage       NaN        4.000000
#                canned    1.180522        3.666667
#                dairy     1.359668        3.666667
#                frozen         NaN        4.000000
#                snacks    1.895046        4.000000
# New York       beverage  1.446199        3.500000
#                canned         NaN        1.000000
#                dairy     1.576848        3.000000
#                frozen         NaN        4.000000
#                snacks    0.565685        3.000000
# Phoenix        beverage       NaN        1.000000
#                canned    0.939486        3.333333
#                dairy     0.388909        1.500000
#                frozen    0.948543        3.000000

# %% [markdown]
# ## ✅ References
# - [User guide](https://pandas.pydata.org/pandas-docs/stable/user_guide/index.html)
# - [Cheat sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
